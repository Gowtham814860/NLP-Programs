# %%
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
words=["playing","played","singing","falling"]
for word in words:
    print(word,"----->",stemmer.stem(word))
# Out:
# playing -----> play
# played -----> play
# singing -----> sing
# falling -----> fall
