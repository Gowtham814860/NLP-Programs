# %%
# !py -m pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (0.20.1)
# Requirement already satisfied: nltk>=3.9 in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from textblob) (3.10.3)
# Requirement already satisfied: defusedxml in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (8.5.0)
# Requirement already satisfied: joblib in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (1.6.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (2026.9.3)
# Requirement already satisfied: tqdm in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (4.70.0)
# Requirement already satisfied: cloudpickle>=3.0 in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from joblib->nltk>=3.9->textblob) (3.1.2)
# Requirement already satisfied: colorama in c:\users\gowtham singh\appdata\local\programs\python\python313\lib\site-packages (from tqdm->nltk>=3.9->textblob) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: C:\Users\Gowtham singh\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

text = "I havv a goood book"
corrected = TextBlob(text).correct()
print(corrected)
# Out:
# I have a good book
